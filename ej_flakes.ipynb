# %%
import warnings
warnings.filterwarnings('ignore')
import flowermd
import hoomd
import gsd
import matplotlib.pyplot as plt
import numpy as np
import gsd.hoomd
from flowermd.base import Pack, Simulation
from flowermd.library import KremerGrestBeadSpring, LJChain
from flowermd.utils import get_target_box_number_density
from flowermd.base import Molecule
from flowermd.library import Graphene
from flowermd.library.forcefields import BeadSpring
from flowermd.base.forcefield import BaseHOOMDForcefield
import unyt as u
import hoomd
import mbuild as mb
import numpy as np
from cmeutils.visualize import FresnelGSD
cpu = hoomd.device.CPU()

# %%
import mbuild as mb
from mbuild.compound import Compound
from mbuild.lattice import Lattice

from flowermd.base import Molecule, System


class Graphene(System):
    def __init__(
        self,
        x_repeat,
        y_repeat,
        n_layers,
        base_units=dict(),
        periodicity=(True, True, False),
    ):
        surface = mb.Compound(periodicity=periodicity)
        scale = 0.246 # 1.0 for testing, 0.246 for graphene bond lengths
        spacings = [s * scale for s in [1.0, 1.0, 1.0]]
        points = [[0, 0, 0], [2/3, 1/3, 0]]
        lattice = Lattice(
            lattice_spacing=spacings,
            angles=[90, 90, 120],
            lattice_points={"A": points},
        )
        carbon = Compound(name="C", element="C")
        layers = lattice.populate(
            compound_dict={"A": carbon}, x=x_repeat, y=y_repeat, z=n_layers
        )
        surface.add(layers)
        surface.freud_generate_bonds("C", "C", dmin=0.3*scale, dmax=0.6*scale)
        surface_mol = Molecule(num_mols=1, compound=surface)
        super(Graphene, self).__init__(
            molecules=[surface_mol],
            base_units=base_units,
        )

    def _build_system(self):
        return self.all_molecules[0]

# %%
#OK, so we want to initialize a system with some chains and some flakes
kg_chain = LJChain(lengths=10,num_mols=15)
sheet = Graphene(x_repeat=5, y_repeat=5, n_layers=1, periodicity=(False, False, False))
system = Pack(molecules=[Molecule(compound=sheet.all_molecules[0], num_mols=5), kg_chain], density=0.1)

# %%
s = 0.246 # 1.0 for scaling

# %%
#system.hoomd_snapshot.configuration.box = [15, 15, 15, 0, 0, 0]

# %%
ff = BeadSpring(r_cut=2.5,
        beads={"A": dict(epsilon=.05, sigma=1.0*s),
               "C": dict(epsilon=0.05, sigma=1.0*s)},
        bonds={"C-C": dict(r0=0.57736*s, k=500), "A-A": dict(r0=1.1, k=0.01)},
        angles={"A-A-A": dict(t0=np.pi, k=0.1),
                "C-C-C": dict(t0=2*np.pi/3., k=500)},
        dihedrals={"A-A-A-A": dict(phi0=0.0, k=0.1, d=-1, n=1), "C-C-C-C": dict(phi0=0.1, k=0.1, d=-1, n=1)})
sim = Simulation(initial_state=system.hoomd_snapshot, forcefield=ff.hoomd_forces, device=cpu, dt = 0.001, gsd_write_freq=int(1000))
#sim.state.thermalize_particle_momenta(filter=hoomd.filter.All(), kT=1.0)
sim.run_NVT(n_steps=3000,kT=0.1, tau_kt = 0.1) #short for initial testing
sim.run_NVT(n_steps=2e5,kT=2, tau_kt = 0.1) #short for initial testing
sim.flush_writers()
sim_visualizer = FresnelGSD(gsd_file="trajectory.gsd", frame=2, view_axis=(1, 1, 1))
sim_visualizer.view()
# dt of .0001 is as big as we can get with the current parameterization
#Issues:
# Graphene flakes are initialized way too small, or the bond lengths are wrong
# Need to double-check all the bonds, angle, dihedral parameters
# then need to go back and get some chain lengths and flake sizes right.
# Out:
# Initializing simulation state from a gsd.hoomd.Frame.
# Step 1000 of 3000; TPS: 3284.64; ETA: 0.0 minutes
# Step 2000 of 3000; TPS: 4590.05; ETA: 0.0 minutes
# Step 0 of 200000; TPS: 0.0; ETA: nan hours, nan minutes
# Step 1000 of 200000; TPS: 6725.31; ETA: 0.5 minutes
# Step 2000 of 200000; TPS: 6889.88; ETA: 0.5 minutes
# Step 3000 of 200000; TPS: 6945.81; ETA: 0.5 minutes
# Step 4000 of 200000; TPS: 6939.78; ETA: 0.5 minutes
# Step 5000 of 200000; TPS: 6950.57; ETA: 0.5 minutes
# Step 6000 of 200000; TPS: 6946.41; ETA: 0.5 minutes
# Step 7000 of 200000; TPS: 6817.5; ETA: 0.5 minutes
# Step 8000 of 200000; TPS: 6805.56; ETA: 0.5 minutes
# Step 9000 of 200000; TPS: 6841.34; ETA: 0.5 minutes
# Step 10000 of 200000; TPS: 6865.68; ETA: 0.5 minutes
# Step 11000 of 200000; TPS: 6863.44; ETA: 0.5 minutes
# Step 12000 of 200000; TPS: 6868.93; ETA: 0.5 minutes
# Step 13000 of 200000; TPS: 6883.08; ETA: 0.5 minutes
# Step 14000 of 200000; TPS: 6890.22; ETA: 0.4 minutes
# Step 15000 of 200000; TPS: 6904.79; ETA: 0.4 minutes
# Step 16000 of 200000; TPS: 6906.83; ETA: 0.4 minutes
# Step 17000 of 200000; TPS: 6906.24; ETA: 0.4 minutes
# Step 18000 of 200000; TPS: 6901.32; ETA: 0.4 minutes
# Step 19000 of 200000; TPS: 6906.53; ETA: 0.4 minutes
# Step 20000 of 200000; TPS: 6898.58; ETA: 0.4 minutes
# Step 21000 of 200000; TPS: 6894.95; ETA: 0.4 minutes
# Step 22000 of 200000; TPS: 6889.93; ETA: 0.4 minutes
# Step 23000 of 200000; TPS: 6893.33; ETA: 0.4 minutes
# Step 24000 of 200000; TPS: 6896.92; ETA: 0.4 minutes
# Step 25000 of 200000; TPS: 6906.78; ETA: 0.4 minutes
# Step 26000 of 200000; TPS: 6914.83; ETA: 0.4 minutes
# Step 27000 of 200000; TPS: 6913.29; ETA: 0.4 minutes
# Step 28000 of 200000; TPS: 6919.55; ETA: 0.4 minutes
# Step 29000 of 200000; TPS: 6829.07; ETA: 0.4 minutes
# Step 30000 of 200000; TPS: 6833.32; ETA: 0.4 minutes
# Step 31000 of 200000; TPS: 6844.05; ETA: 0.4 minutes
# Step 32000 of 200000; TPS: 6855.62; ETA: 0.4 minutes
# Step 33000 of 200000; TPS: 6861.56; ETA: 0.4 minutes
# Step 34000 of 200000; TPS: 6869.42; ETA: 0.4 minutes
# Step 35000 of 200000; TPS: 6865.36; ETA: 0.4 minutes
# Step 36000 of 200000; TPS: 6871.97; ETA: 0.4 minutes
# Step 37000 of 200000; TPS: 6875.69; ETA: 0.4 minutes
# Step 38000 of 200000; TPS: 6881.64; ETA: 0.4 minutes
# Step 39000 of 200000; TPS: 6883.67; ETA: 0.4 minutes
# Step 40000 of 200000; TPS: 6892.68; ETA: 0.4 minutes
# Step 41000 of 200000; TPS: 6902.7; ETA: 0.4 minutes
# Step 42000 of 200000; TPS: 6852.54; ETA: 0.4 minutes
# Step 43000 of 200000; TPS: 6857.4; ETA: 0.4 minutes
# Step 44000 of 200000; TPS: 6857.18; ETA: 0.4 minutes
# Step 45000 of 200000; TPS: 6857.92; ETA: 0.4 minutes
# Step 46000 of 200000; TPS: 6861.4; ETA: 0.4 minutes
# Step 47000 of 200000; TPS: 6868.6; ETA: 0.4 minutes
# Step 48000 of 200000; TPS: 6875.06; ETA: 0.4 minutes
# Step 49000 of 200000; TPS: 6878.5; ETA: 0.4 minutes
# Step 50000 of 200000; TPS: 6875.22; ETA: 0.4 minutes
# Step 51000 of 200000; TPS: 6875.53; ETA: 0.4 minutes
# Step 52000 of 200000; TPS: 6874.8; ETA: 0.4 minutes
# Step 53000 of 200000; TPS: 6876.53; ETA: 0.4 minutes
# Step 54000 of 200000; TPS: 6876.6; ETA: 0.4 minutes
# Step 55000 of 200000; TPS: 6877.37; ETA: 0.4 minutes
# Step 56000 of 200000; TPS: 6878.42; ETA: 0.3 minutes
# Step 57000 of 200000; TPS: 6881.91; ETA: 0.3 minutes
# Step 58000 of 200000; TPS: 6881.69; ETA: 0.3 minutes
# Step 59000 of 200000; TPS: 6857.53; ETA: 0.3 minutes
# Step 60000 of 200000; TPS: 6860.01; ETA: 0.3 minutes
# Step 61000 of 200000; TPS: 6864.64; ETA: 0.3 minutes
# Step 62000 of 200000; TPS: 6866.03; ETA: 0.3 minutes
# Step 63000 of 200000; TPS: 6867.52; ETA: 0.3 minutes
# Step 64000 of 200000; TPS: 6870.48; ETA: 0.3 minutes
# Step 65000 of 200000; TPS: 6873.99; ETA: 0.3 minutes
# Step 66000 of 200000; TPS: 6877.73; ETA: 0.3 minutes
# Step 67000 of 200000; TPS: 6881.14; ETA: 0.3 minutes
# Step 68000 of 200000; TPS: 6883.15; ETA: 0.3 minutes
# Step 69000 of 200000; TPS: 6887.1; ETA: 0.3 minutes
# Step 70000 of 200000; TPS: 6892.38; ETA: 0.3 minutes
# Step 71000 of 200000; TPS: 6894.98; ETA: 0.3 minutes
# Step 72000 of 200000; TPS: 6898.85; ETA: 0.3 minutes
# Step 73000 of 200000; TPS: 6901.13; ETA: 0.3 minutes
# Step 74000 of 200000; TPS: 6905.37; ETA: 0.3 minutes
# Step 75000 of 200000; TPS: 6909.31; ETA: 0.3 minutes
# Step 76000 of 200000; TPS: 6913.8; ETA: 0.3 minutes
# Step 77000 of 200000; TPS: 6911.4; ETA: 0.3 minutes
# Step 78000 of 200000; TPS: 6913.28; ETA: 0.3 minutes
# Step 79000 of 200000; TPS: 6917.25; ETA: 0.3 minutes
# Step 80000 of 200000; TPS: 6920.91; ETA: 0.3 minutes
# Step 81000 of 200000; TPS: 6923.44; ETA: 0.3 minutes
# Step 82000 of 200000; TPS: 6926.11; ETA: 0.3 minutes
# Step 83000 of 200000; TPS: 6924.64; ETA: 0.3 minutes
# Step 84000 of 200000; TPS: 6928.53; ETA: 0.3 minutes
# Step 85000 of 200000; TPS: 6930.5; ETA: 0.3 minutes
# Step 86000 of 200000; TPS: 6931.23; ETA: 0.3 minutes
# Step 87000 of 200000; TPS: 6931.36; ETA: 0.3 minutes
# Step 88000 of 200000; TPS: 6933.28; ETA: 0.3 minutes
# Step 89000 of 200000; TPS: 6930.4; ETA: 0.3 minutes
# Step 90000 of 200000; TPS: 6927.77; ETA: 0.3 minutes
# Step 91000 of 200000; TPS: 6924.12; ETA: 0.3 minutes
# Step 92000 of 200000; TPS: 6919.2; ETA: 0.3 minutes
# Step 93000 of 200000; TPS: 6915.08; ETA: 0.3 minutes
# Step 94000 of 200000; TPS: 6906.31; ETA: 0.3 minutes
# Step 95000 of 200000; TPS: 6899.36; ETA: 0.3 minutes
# Step 96000 of 200000; TPS: 6893.31; ETA: 0.3 minutes
# Step 97000 of 200000; TPS: 6876.35; ETA: 0.2 minutes
# Step 98000 of 200000; TPS: 6871.81; ETA: 0.2 minutes
# Step 99000 of 200000; TPS: 6830.51; ETA: 0.2 minutes
# Step 100000 of 200000; TPS: 6826.49; ETA: 0.2 minutes
# Step 101000 of 200000; TPS: 6820.21; ETA: 0.2 minutes
# Step 102000 of 200000; TPS: 6815.95; ETA: 0.2 minutes
# Step 103000 of 200000; TPS: 6812.67; ETA: 0.2 minutes
# Step 104000 of 200000; TPS: 6808.71; ETA: 0.2 minutes
# Step 105000 of 200000; TPS: 6807.14; ETA: 0.2 minutes
# Step 106000 of 200000; TPS: 6806.48; ETA: 0.2 minutes
# Step 107000 of 200000; TPS: 6807.4; ETA: 0.2 minutes
# Step 108000 of 200000; TPS: 6811.09; ETA: 0.2 minutes
# Step 109000 of 200000; TPS: 6813.23; ETA: 0.2 minutes
# Step 110000 of 200000; TPS: 6814.64; ETA: 0.2 minutes
# Step 111000 of 200000; TPS: 6812.58; ETA: 0.2 minutes
# Step 112000 of 200000; TPS: 6812.08; ETA: 0.2 minutes
# Step 113000 of 200000; TPS: 6812.08; ETA: 0.2 minutes
# Step 114000 of 200000; TPS: 6813.12; ETA: 0.2 minutes
# Step 115000 of 200000; TPS: 6813.48; ETA: 0.2 minutes
# Step 116000 of 200000; TPS: 6814.34; ETA: 0.2 minutes
# Step 117000 of 200000; TPS: 6814.56; ETA: 0.2 minutes
# Step 118000 of 200000; TPS: 6811.81; ETA: 0.2 minutes
# Step 119000 of 200000; TPS: 6809.69; ETA: 0.2 minutes
# Step 120000 of 200000; TPS: 6807.07; ETA: 0.2 minutes
# Step 121000 of 200000; TPS: 6802.7; ETA: 0.2 minutes
# Step 122000 of 200000; TPS: 6784.14; ETA: 0.2 minutes
# Step 123000 of 200000; TPS: 6780.54; ETA: 0.2 minutes
# Step 124000 of 200000; TPS: 6778.24; ETA: 0.2 minutes
# Step 125000 of 200000; TPS: 6772.76; ETA: 0.2 minutes
# Step 126000 of 200000; TPS: 6766.91; ETA: 0.2 minutes
# Step 127000 of 200000; TPS: 6760.02; ETA: 0.2 minutes
# Step 128000 of 200000; TPS: 6754.39; ETA: 0.2 minutes
# Step 129000 of 200000; TPS: 6750.04; ETA: 0.2 minutes
# Step 130000 of 200000; TPS: 6747.01; ETA: 0.2 minutes
# Step 131000 of 200000; TPS: 6743.39; ETA: 0.2 minutes
# Step 132000 of 200000; TPS: 6740.76; ETA: 0.2 minutes
# Step 133000 of 200000; TPS: 6737.36; ETA: 0.2 minutes
# Step 134000 of 200000; TPS: 6735.42; ETA: 0.2 minutes
# Step 135000 of 200000; TPS: 6734.1; ETA: 0.2 minutes
# Step 136000 of 200000; TPS: 6732.21; ETA: 0.2 minutes
# Step 137000 of 200000; TPS: 6731.94; ETA: 0.2 minutes
# Step 138000 of 200000; TPS: 6726.51; ETA: 0.2 minutes
# Step 139000 of 200000; TPS: 6725.35; ETA: 0.2 minutes
# Step 140000 of 200000; TPS: 6723.48; ETA: 0.1 minutes
# Step 141000 of 200000; TPS: 6720.78; ETA: 0.1 minutes
# Step 142000 of 200000; TPS: 6717.15; ETA: 0.1 minutes
# Step 143000 of 200000; TPS: 6715.27; ETA: 0.1 minutes
# Step 144000 of 200000; TPS: 6715.0; ETA: 0.1 minutes
# Step 145000 of 200000; TPS: 6713.67; ETA: 0.1 minutes
# Step 146000 of 200000; TPS: 6715.16; ETA: 0.1 minutes
# Step 147000 of 200000; TPS: 6714.69; ETA: 0.1 minutes
# Step 148000 of 200000; TPS: 6716.07; ETA: 0.1 minutes
# Step 149000 of 200000; TPS: 6717.26; ETA: 0.1 minutes
# Step 150000 of 200000; TPS: 6718.32; ETA: 0.1 minutes
# Step 151000 of 200000; TPS: 6719.23; ETA: 0.1 minutes
# Step 152000 of 200000; TPS: 6720.45; ETA: 0.1 minutes
# Step 153000 of 200000; TPS: 6722.39; ETA: 0.1 minutes
# Step 154000 of 200000; TPS: 6724.82; ETA: 0.1 minutes
# Step 155000 of 200000; TPS: 6727.4; ETA: 0.1 minutes
# Step 156000 of 200000; TPS: 6730.06; ETA: 0.1 minutes
# Step 157000 of 200000; TPS: 6732.85; ETA: 0.1 minutes
# Step 158000 of 200000; TPS: 6735.71; ETA: 0.1 minutes
# Step 159000 of 200000; TPS: 6737.12; ETA: 0.1 minutes
# Step 160000 of 200000; TPS: 6739.73; ETA: 0.1 minutes
# Step 161000 of 200000; TPS: 6742.42; ETA: 0.1 minutes
# Step 162000 of 200000; TPS: 6744.56; ETA: 0.1 minutes
# Step 163000 of 200000; TPS: 6746.67; ETA: 0.1 minutes
# Step 164000 of 200000; TPS: 6748.7; ETA: 0.1 minutes
# Step 165000 of 200000; TPS: 6751.57; ETA: 0.1 minutes
# Step 166000 of 200000; TPS: 6753.61; ETA: 0.1 minutes
# Step 167000 of 200000; TPS: 6756.18; ETA: 0.1 minutes
# Step 168000 of 200000; TPS: 6758.12; ETA: 0.1 minutes
# Step 169000 of 200000; TPS: 6760.14; ETA: 0.1 minutes
# Step 170000 of 200000; TPS: 6762.44; ETA: 0.1 minutes
# Step 171000 of 200000; TPS: 6764.3; ETA: 0.1 minutes
# Step 172000 of 200000; TPS: 6766.34; ETA: 0.1 minutes
# Step 173000 of 200000; TPS: 6768.69; ETA: 0.1 minutes
# Step 174000 of 200000; TPS: 6770.46; ETA: 0.1 minutes
# Step 175000 of 200000; TPS: 6773.15; ETA: 0.1 minutes
# Step 176000 of 200000; TPS: 6774.91; ETA: 0.1 minutes
# Step 177000 of 200000; TPS: 6777.41; ETA: 0.1 minutes
# Step 178000 of 200000; TPS: 6779.57; ETA: 0.1 minutes
# Step 179000 of 200000; TPS: 6780.79; ETA: 0.1 minutes
# Step 180000 of 200000; TPS: 6782.98; ETA: 0.0 minutes
# Step 181000 of 200000; TPS: 6785.46; ETA: 0.0 minutes
# Step 182000 of 200000; TPS: 6787.87; ETA: 0.0 minutes
# Step 183000 of 200000; TPS: 6789.42; ETA: 0.0 minutes
# Step 184000 of 200000; TPS: 6791.82; ETA: 0.0 minutes
# Step 185000 of 200000; TPS: 6794.25; ETA: 0.0 minutes
# Step 186000 of 200000; TPS: 6796.67; ETA: 0.0 minutes
# Step 187000 of 200000; TPS: 6797.72; ETA: 0.0 minutes
# Step 188000 of 200000; TPS: 6798.87; ETA: 0.0 minutes
# Step 189000 of 200000; TPS: 6801.05; ETA: 0.0 minutes
# Step 190000 of 200000; TPS: 6803.92; ETA: 0.0 minutes
# Step 191000 of 200000; TPS: 6805.59; ETA: 0.0 minutes
# Step 192000 of 200000; TPS: 6808.03; ETA: 0.0 minutes
# Step 193000 of 200000; TPS: 6809.21; ETA: 0.0 minutes
# Step 194000 of 200000; TPS: 6811.31; ETA: 0.0 minutes
# Step 195000 of 200000; TPS: 6812.08; ETA: 0.0 minutes
# Step 196000 of 200000; TPS: 6813.89; ETA: 0.0 minutes
# Step 197000 of 200000; TPS: 6815.07; ETA: 0.0 minutes
# Step 198000 of 200000; TPS: 6815.94; ETA: 0.0 minutes
# Step 199000 of 200000; TPS: 6816.83; ETA: 0.0 minutes
