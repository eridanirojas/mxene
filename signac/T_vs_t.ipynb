# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt("ej_flakes.txt", names=True)
T = data["mdcomputeThermodynamicQuantitieskinetic_temperature"]
t = data["flowermdbasesimulationSimulationtimestep"]

# %%
plt.plot(T,t)
