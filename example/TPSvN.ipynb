# %%
import numpy as np
import matplotlib.pyplot as plt

# Load arrays from text files
N = np.loadtxt('N.txt')
tps = np.loadtxt('tps.txt')
PE = np.loadtxt('PE.txt')
timesteps = np.loadtxt('timesteps.txt')
densities = np.loadtxt('densities.txt')
dts = np.loadtxt('dts.txt')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from tqdm import tqdm
#       5 # Load arrays from text files
#       6 N = np.loadtxt('N.txt')
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
N[4]
# Out:
# 500.0

# %%
plt.plot(N, tps)
plt.xlabel("N")
plt.ylabel("tps")
plt.title("tps vs N")
plt.grid(True)
plt.show()
