# %%
import flowermd
import gsd
import gsd.hoomd
import hoomd
import matplotlib.pyplot as plt
import mbuild as mb
import numpy as np
import warnings
from cmeutils.visualize import FresnelGSD
from flowermd.base import Pack, Simulation, System, Molecule
from flowermd.base.forcefield import BaseHOOMDForcefield
from flowermd.library import KremerGrestBeadSpring#, LJChain
from flowermd.library.forcefields import BeadSpring
from flowermd.utils import get_target_box_number_density
from mbuild.compound import Compound
from mbuild.lattice import Lattice
warnings.filterwarnings('ignore')
import mbuild as mb
import numpy as np
import random
from math import radians
from flowermd import Polymer

class LJChain(Polymer):
    """Create a coarse-grained bead-spring polymer chain with random-walk geometry."""

    def __init__(
        self,
        lengths,
        num_mols,
        bead_sequence=["A"],
        bead_mass={"A": 1.0},
        bond_lengths={"A-A": 1.0},
    ):
        self.bead_sequence = bead_sequence
        self.bead_mass = bead_mass
        self.bond_lengths = bond_lengths
        super(LJChain, self).__init__(lengths=lengths, num_mols=num_mols)

    def _build(self, length):
        chain = mb.Compound()
        last_bead = None
        direction = np.array([0, 0, 1])  # Start along +z
        for i in range(length):
            for idx, bead_type in enumerate(self.bead_sequence):
                mass = self.bead_mass.get(bead_type, None)
                if not mass:
                    raise ValueError(
                        f"The bead mass for {bead_type} was not given in bead_mass."
                    )
                next_bead = mb.Compound(name=bead_type, mass=mass, charge=0)
                chain.add(next_bead)
                if last_bead is not None:
                    bead_pair = f"{last_bead.name}-{next_bead.name}"
                    bond_length = self.bond_lengths.get(
                        bead_pair, self.bond_lengths.get(f"{next_bead.name}-{last_bead.name}", None)
                    )
                    if bond_length is None:
                        raise ValueError(
                            f"Missing bond length for pair: {bead_pair}"
                        )
                    # Random angle between -30° and +30°
                    angle_deg = random.uniform(-30, 30)
                    angle_rad = radians(angle_deg)
                    # Rotate direction around a random perpendicular axis
                    axis = np.random.randn(3)
                    axis -= axis.dot(direction) * direction  # Make perpendicular to direction
                    axis /= np.linalg.norm(axis)
                    # Rotation matrix using Rodrigues' rotation formula
                    K = np.array([
                        [0, -axis[2], axis[1]],
                        [axis[2], 0, -axis[0]],
                        [-axis[1], axis[0], 0]
                    ])
                    R = np.eye(3) + np.sin(angle_rad) * K + (1 - np.cos(angle_rad)) * (K @ K)
                    direction = R @ direction
                    direction /= np.linalg.norm(direction)
                    new_pos = last_bead.xyz[0] + bond_length * direction
                    next_bead.translate_to(new_pos)
                    chain.add_bond([last_bead, next_bead])
                else:
                    # First bead at origin
                    next_bead.translate_to([0, 0, 0])
                last_bead = next_bead
        return chain
class Graphene(System):
    def __init__(
        self,
        x_repeat,
        y_repeat,
        n_layers,
        base_units=dict(),
        periodicity=(True, True, False),
    ):
        surface = mb.Compound(periodicity=periodicity)
        a = 3**.5
        lattice = Lattice(
            lattice_spacing=[a,a,a],
            lattice_vectors=  [[a,0,0],[a/2,3/2,0],[0,0,1]],
            lattice_points={"A": [[1/3,1/3,0], [2/3, 2/3, 0]]},
        ) 
        Flakium = Compound(name="F", element="F") # defines a carbon atom that will be used to populate lattice points
        layers = lattice.populate(
            compound_dict={"A": Flakium}, x=x_repeat, y=y_repeat, z=n_layers
        ) # populates the lattice using the previously defined carbon atom for every "A" site, repeated in all x,y, and z directions
        surface.add(layers) # adds populated carbon lattice layers to the 'surface' compound, which represents our graphene structure 
        surface.freud_generate_bonds("F", "F", dmin=0.9, dmax=1.1) # generates bonds depending on input distance range, scales with lattice
        surface_mol = Molecule(num_mols=1, compound=surface) # wraps into a Molecule object, creating "1" instance of this molecule

        super(Graphene, self).__init__(
            molecules=[surface_mol],
            base_units=base_units,
        )

    def _build_system(self):
        return self.all_molecules[0]
#OK, so we want to initialize a system with some chains and some flakes
kg_chain = LJChain(lengths=20,num_mols=15)
sheet = Graphene(x_repeat=5, y_repeat=5, n_layers=1, periodicity=(False, False, False))
system = Pack(molecules=[Molecule(compound=sheet.all_molecules[0], num_mols=12), kg_chain], density=0.1, packing_expand_factor = 6, seed=2, overlap = 1.1)
system.visualize()

# %%
# this FF is for research question
ff = BeadSpring(
    r_cut=2.5,  
    beads={
        "A": dict(epsilon=1.0, sigma=1.0),  # chains
        "F": dict(epsilon=1.0, sigma=1.0),  # flakes
    },
    bonds={
        "F-F": dict(r0=1.0, k=1000),
        "A-A": dict(r0=1.0, k=1000.0),  # increased k to avoid chain collapse
    },
    angles={
        "A-A-A": dict(t0=2* np.pi / 3., k=100.0),   # moderate stiffness for chains
        "F-F-F": dict(t0=2 * np.pi / 3., k=5000),
    },
    dihedrals={
        "A-A-A-A": dict(phi0=0.0, k=0, d=-1, n=2), #need to turn this on later, messed up with straight chains
        "F-F-F-F": dict(phi0=0.0, k=500, d=-1, n=2),
    }
)
gsd ="20_20ch12f_0005dt.gsd"
log ="20_20ch12f_0005dt.txt"
cpu = hoomd.device.CPU()
sim = Simulation(initial_state=system.hoomd_snapshot, forcefield=ff.hoomd_forces, device=cpu, dt = 0.0005, gsd_write_freq=int(1000), log_file_name = log, gsd_file_name = gsd)
sim.run_NVT(n_steps=200000, kT=1, tau_kt=.1)
sim.flush_writers()
sim_visualizer = FresnelGSD(gsd_file=gsd, frame=-1, view_axis=(1, 1, 1))
sim_visualizer.view()
# Out:
# *Warning*: dihedral.harmonic: specified K <= 0
# Initializing simulation state from a gsd.hoomd.Frame.
# Step 1000 of 200000; TPS: 1880.42; ETA: 1.8 minutes
# Step 2000 of 200000; TPS: 2513.84; ETA: 1.3 minutes
# Step 3000 of 200000; TPS: 2841.32; ETA: 1.2 minutes
# Step 4000 of 200000; TPS: 3024.34; ETA: 1.1 minutes
# Step 5000 of 200000; TPS: 3146.11; ETA: 1.0 minutes
# Step 6000 of 200000; TPS: 3234.86; ETA: 1.0 minutes
# Step 7000 of 200000; TPS: 3308.32; ETA: 1.0 minutes
# Step 8000 of 200000; TPS: 3345.98; ETA: 1.0 minutes
# Step 9000 of 200000; TPS: 3365.19; ETA: 0.9 minutes
# Step 10000 of 200000; TPS: 3374.07; ETA: 0.9 minutes
# Step 11000 of 200000; TPS: 3395.86; ETA: 0.9 minutes
# Step 12000 of 200000; TPS: 3418.82; ETA: 0.9 minutes
# Step 13000 of 200000; TPS: 3425.9; ETA: 0.9 minutes
# Step 14000 of 200000; TPS: 3439.68; ETA: 0.9 minutes
# Step 15000 of 200000; TPS: 3445.01; ETA: 0.9 minutes
# Step 16000 of 200000; TPS: 3451.25; ETA: 0.9 minutes
# Step 17000 of 200000; TPS: 3456.72; ETA: 0.9 minutes
# Step 18000 of 200000; TPS: 3454.92; ETA: 0.9 minutes
# Step 19000 of 200000; TPS: 3455.24; ETA: 0.9 minutes
# Step 20000 of 200000; TPS: 3449.53; ETA: 0.9 minutes
# Step 21000 of 200000; TPS: 3454.63; ETA: 0.9 minutes
# Step 22000 of 200000; TPS: 3456.25; ETA: 0.9 minutes
# Step 23000 of 200000; TPS: 3448.94; ETA: 0.9 minutes
# Step 24000 of 200000; TPS: 3437.57; ETA: 0.9 minutes
# Step 25000 of 200000; TPS: 3431.73; ETA: 0.8 minutes
# Step 26000 of 200000; TPS: 3429.15; ETA: 0.8 minutes
# Step 27000 of 200000; TPS: 3424.91; ETA: 0.8 minutes
# Step 28000 of 200000; TPS: 3425.05; ETA: 0.8 minutes
# Step 29000 of 200000; TPS: 3428.26; ETA: 0.8 minutes
# Step 30000 of 200000; TPS: 3428.01; ETA: 0.8 minutes
# Step 31000 of 200000; TPS: 3430.86; ETA: 0.8 minutes
# Step 32000 of 200000; TPS: 3428.49; ETA: 0.8 minutes
# Step 33000 of 200000; TPS: 3427.13; ETA: 0.8 minutes
# Step 34000 of 200000; TPS: 3427.89; ETA: 0.8 minutes
# Step 35000 of 200000; TPS: 3425.6; ETA: 0.8 minutes
# Step 36000 of 200000; TPS: 3423.73; ETA: 0.8 minutes
# Step 37000 of 200000; TPS: 3425.55; ETA: 0.8 minutes
# Step 38000 of 200000; TPS: 3420.64; ETA: 0.8 minutes
# Step 39000 of 200000; TPS: 3420.22; ETA: 0.8 minutes
# Step 40000 of 200000; TPS: 3420.33; ETA: 0.8 minutes
# Step 41000 of 200000; TPS: 3421.07; ETA: 0.8 minutes
# Step 42000 of 200000; TPS: 3419.21; ETA: 0.8 minutes
# Step 43000 of 200000; TPS: 3418.3; ETA: 0.8 minutes
# Step 44000 of 200000; TPS: 3416.17; ETA: 0.8 minutes
# Step 45000 of 200000; TPS: 3416.57; ETA: 0.8 minutes
# Step 46000 of 200000; TPS: 3417.76; ETA: 0.8 minutes
# Step 47000 of 200000; TPS: 3418.3; ETA: 0.7 minutes
# Step 48000 of 200000; TPS: 3416.67; ETA: 0.7 minutes
# Step 49000 of 200000; TPS: 3417.39; ETA: 0.7 minutes
# Step 50000 of 200000; TPS: 3417.51; ETA: 0.7 minutes
# Step 51000 of 200000; TPS: 3416.62; ETA: 0.7 minutes
# Step 52000 of 200000; TPS: 3417.56; ETA: 0.7 minutes
# Step 53000 of 200000; TPS: 3417.23; ETA: 0.7 minutes
# Step 54000 of 200000; TPS: 3416.8; ETA: 0.7 minutes
# Step 55000 of 200000; TPS: 3417.89; ETA: 0.7 minutes
# Step 56000 of 200000; TPS: 3419.55; ETA: 0.7 minutes
# Step 57000 of 200000; TPS: 3419.46; ETA: 0.7 minutes
# Step 58000 of 200000; TPS: 3418.36; ETA: 0.7 minutes
# Step 59000 of 200000; TPS: 3417.18; ETA: 0.7 minutes
# Step 60000 of 200000; TPS: 3417.19; ETA: 0.7 minutes
# Step 61000 of 200000; TPS: 3416.23; ETA: 0.7 minutes
# Step 62000 of 200000; TPS: 3415.21; ETA: 0.7 minutes
# Step 63000 of 200000; TPS: 3415.76; ETA: 0.7 minutes
# Step 64000 of 200000; TPS: 3415.27; ETA: 0.7 minutes
# Step 65000 of 200000; TPS: 3412.34; ETA: 0.7 minutes
# Step 66000 of 200000; TPS: 3412.59; ETA: 0.7 minutes
# Step 67000 of 200000; TPS: 3412.13; ETA: 0.6 minutes
# Step 68000 of 200000; TPS: 3412.13; ETA: 0.6 minutes
# Step 69000 of 200000; TPS: 3411.39; ETA: 0.6 minutes
# Step 70000 of 200000; TPS: 3411.33; ETA: 0.6 minutes
# Step 71000 of 200000; TPS: 3410.85; ETA: 0.6 minutes
# Step 72000 of 200000; TPS: 3410.51; ETA: 0.6 minutes
# Step 73000 of 200000; TPS: 3410.81; ETA: 0.6 minutes
# Step 74000 of 200000; TPS: 3410.83; ETA: 0.6 minutes
# Step 75000 of 200000; TPS: 3411.19; ETA: 0.6 minutes
# Step 76000 of 200000; TPS: 3408.1; ETA: 0.6 minutes
# Step 77000 of 200000; TPS: 3405.24; ETA: 0.6 minutes
# Step 78000 of 200000; TPS: 3404.29; ETA: 0.6 minutes
# Step 79000 of 200000; TPS: 3404.14; ETA: 0.6 minutes
# Step 80000 of 200000; TPS: 3403.14; ETA: 0.6 minutes
# Step 81000 of 200000; TPS: 3403.5; ETA: 0.6 minutes
# Step 82000 of 200000; TPS: 3402.9; ETA: 0.6 minutes
# Step 83000 of 200000; TPS: 3401.81; ETA: 0.6 minutes
# Step 84000 of 200000; TPS: 3402.14; ETA: 0.6 minutes
# Step 85000 of 200000; TPS: 3401.12; ETA: 0.6 minutes
# Step 86000 of 200000; TPS: 3400.3; ETA: 0.6 minutes
# Step 87000 of 200000; TPS: 3398.19; ETA: 0.6 minutes
# Step 88000 of 200000; TPS: 3396.52; ETA: 0.5 minutes
# Step 89000 of 200000; TPS: 3395.2; ETA: 0.5 minutes
# Step 90000 of 200000; TPS: 3392.99; ETA: 0.5 minutes
# Step 91000 of 200000; TPS: 3392.12; ETA: 0.5 minutes
# Step 92000 of 200000; TPS: 3390.69; ETA: 0.5 minutes
# Step 93000 of 200000; TPS: 3390.68; ETA: 0.5 minutes
# Step 94000 of 200000; TPS: 3390.44; ETA: 0.5 minutes
# Step 95000 of 200000; TPS: 3388.15; ETA: 0.5 minutes
# Step 96000 of 200000; TPS: 3386.35; ETA: 0.5 minutes
# Step 97000 of 200000; TPS: 3385.83; ETA: 0.5 minutes
# Step 98000 of 200000; TPS: 3384.2; ETA: 0.5 minutes
# Step 99000 of 200000; TPS: 3382.49; ETA: 0.5 minutes
# Step 100000 of 200000; TPS: 3380.75; ETA: 0.5 minutes
# Step 101000 of 200000; TPS: 3379.53; ETA: 0.5 minutes
# Step 102000 of 200000; TPS: 3378.78; ETA: 0.5 minutes
# Step 103000 of 200000; TPS: 3377.12; ETA: 0.5 minutes
# Step 104000 of 200000; TPS: 3375.18; ETA: 0.5 minutes
# Step 105000 of 200000; TPS: 3374.1; ETA: 0.5 minutes
# Step 106000 of 200000; TPS: 3373.11; ETA: 0.5 minutes
# Step 107000 of 200000; TPS: 3370.82; ETA: 0.5 minutes
# Step 108000 of 200000; TPS: 3369.11; ETA: 0.5 minutes
# Step 109000 of 200000; TPS: 3367.27; ETA: 0.5 minutes
# Step 110000 of 200000; TPS: 3365.89; ETA: 0.4 minutes
# Step 111000 of 200000; TPS: 3365.27; ETA: 0.4 minutes
# Step 112000 of 200000; TPS: 3363.6; ETA: 0.4 minutes
# Step 113000 of 200000; TPS: 3363.2; ETA: 0.4 minutes
# Step 114000 of 200000; TPS: 3361.92; ETA: 0.4 minutes
# Step 115000 of 200000; TPS: 3360.77; ETA: 0.4 minutes
# Step 116000 of 200000; TPS: 3359.96; ETA: 0.4 minutes
# Step 117000 of 200000; TPS: 3358.41; ETA: 0.4 minutes
# Step 118000 of 200000; TPS: 3357.47; ETA: 0.4 minutes
# Step 119000 of 200000; TPS: 3355.56; ETA: 0.4 minutes
# Step 120000 of 200000; TPS: 3353.82; ETA: 0.4 minutes
# Step 121000 of 200000; TPS: 3352.54; ETA: 0.4 minutes
# Step 122000 of 200000; TPS: 3351.28; ETA: 0.4 minutes
# Step 123000 of 200000; TPS: 3349.6; ETA: 0.4 minutes
# Step 124000 of 200000; TPS: 3348.39; ETA: 0.4 minutes
# Step 125000 of 200000; TPS: 3346.0; ETA: 0.4 minutes
# Step 126000 of 200000; TPS: 3344.75; ETA: 0.4 minutes
# Step 127000 of 200000; TPS: 3343.22; ETA: 0.4 minutes
# Step 128000 of 200000; TPS: 3341.25; ETA: 0.4 minutes
# Step 129000 of 200000; TPS: 3339.43; ETA: 0.4 minutes
# Step 130000 of 200000; TPS: 3337.75; ETA: 0.3 minutes
# Step 131000 of 200000; TPS: 3336.31; ETA: 0.3 minutes
# Step 132000 of 200000; TPS: 3334.9; ETA: 0.3 minutes
# Step 133000 of 200000; TPS: 3333.51; ETA: 0.3 minutes
# Step 134000 of 200000; TPS: 3332.42; ETA: 0.3 minutes
# Step 135000 of 200000; TPS: 3330.96; ETA: 0.3 minutes
# Step 136000 of 200000; TPS: 3329.08; ETA: 0.3 minutes
# Step 137000 of 200000; TPS: 3327.82; ETA: 0.3 minutes
# Step 138000 of 200000; TPS: 3326.04; ETA: 0.3 minutes
# Step 139000 of 200000; TPS: 3324.5; ETA: 0.3 minutes
# Step 140000 of 200000; TPS: 3323.1; ETA: 0.3 minutes
# Step 141000 of 200000; TPS: 3321.57; ETA: 0.3 minutes
# Step 142000 of 200000; TPS: 3320.62; ETA: 0.3 minutes
# Step 143000 of 200000; TPS: 3319.47; ETA: 0.3 minutes
# Step 144000 of 200000; TPS: 3318.34; ETA: 0.3 minutes
# Step 145000 of 200000; TPS: 3317.16; ETA: 0.3 minutes
# Step 146000 of 200000; TPS: 3316.22; ETA: 0.3 minutes
# Step 147000 of 200000; TPS: 3314.79; ETA: 0.3 minutes
# Step 148000 of 200000; TPS: 3313.83; ETA: 0.3 minutes
# Step 149000 of 200000; TPS: 3311.55; ETA: 0.3 minutes
# Step 150000 of 200000; TPS: 3310.78; ETA: 0.3 minutes
# Step 151000 of 200000; TPS: 3308.88; ETA: 0.2 minutes
# Step 152000 of 200000; TPS: 3307.76; ETA: 0.2 minutes
# Step 153000 of 200000; TPS: 3306.32; ETA: 0.2 minutes
# Step 154000 of 200000; TPS: 3305.06; ETA: 0.2 minutes
# Step 155000 of 200000; TPS: 3303.25; ETA: 0.2 minutes
# Step 156000 of 200000; TPS: 3302.25; ETA: 0.2 minutes
# Step 157000 of 200000; TPS: 3300.74; ETA: 0.2 minutes
# Step 158000 of 200000; TPS: 3299.36; ETA: 0.2 minutes
# Step 159000 of 200000; TPS: 3297.52; ETA: 0.2 minutes
# Step 160000 of 200000; TPS: 3296.16; ETA: 0.2 minutes
# Step 161000 of 200000; TPS: 3295.09; ETA: 0.2 minutes
# Step 162000 of 200000; TPS: 3293.92; ETA: 0.2 minutes
# Step 163000 of 200000; TPS: 3292.27; ETA: 0.2 minutes
# Step 164000 of 200000; TPS: 3290.77; ETA: 0.2 minutes
# Step 165000 of 200000; TPS: 3288.92; ETA: 0.2 minutes
# Step 166000 of 200000; TPS: 3287.59; ETA: 0.2 minutes
# Step 167000 of 200000; TPS: 3286.06; ETA: 0.2 minutes
# Step 168000 of 200000; TPS: 3284.8; ETA: 0.2 minutes
# Step 169000 of 200000; TPS: 3282.68; ETA: 0.2 minutes
# Step 170000 of 200000; TPS: 3281.85; ETA: 0.2 minutes
# Step 171000 of 200000; TPS: 3279.7; ETA: 0.1 minutes
# Step 172000 of 200000; TPS: 3278.12; ETA: 0.1 minutes
# Step 173000 of 200000; TPS: 3276.18; ETA: 0.1 minutes
# Step 174000 of 200000; TPS: 3274.34; ETA: 0.1 minutes
# Step 175000 of 200000; TPS: 3273.12; ETA: 0.1 minutes
# Step 176000 of 200000; TPS: 3271.58; ETA: 0.1 minutes
# Step 177000 of 200000; TPS: 3269.54; ETA: 0.1 minutes
# Step 178000 of 200000; TPS: 3268.7; ETA: 0.1 minutes
# Step 179000 of 200000; TPS: 3267.52; ETA: 0.1 minutes
# Step 180000 of 200000; TPS: 3264.8; ETA: 0.1 minutes
# Step 181000 of 200000; TPS: 3262.46; ETA: 0.1 minutes
# Step 182000 of 200000; TPS: 3261.1; ETA: 0.1 minutes
# Step 183000 of 200000; TPS: 3259.25; ETA: 0.1 minutes
# Step 184000 of 200000; TPS: 3257.77; ETA: 0.1 minutes
# Step 185000 of 200000; TPS: 3256.56; ETA: 0.1 minutes
# Step 186000 of 200000; TPS: 3255.56; ETA: 0.1 minutes
# Step 187000 of 200000; TPS: 3254.51; ETA: 0.1 minutes
# Step 188000 of 200000; TPS: 3253.39; ETA: 0.1 minutes
# Step 189000 of 200000; TPS: 3252.37; ETA: 0.1 minutes
# Step 190000 of 200000; TPS: 3251.27; ETA: 0.1 minutes
# Step 191000 of 200000; TPS: 3250.1; ETA: 0.0 minutes
# Step 192000 of 200000; TPS: 3248.71; ETA: 0.0 minutes
# Step 193000 of 200000; TPS: 3247.56; ETA: 0.0 minutes
# Step 194000 of 200000; TPS: 3246.3; ETA: 0.0 minutes
# Step 195000 of 200000; TPS: 3244.81; ETA: 0.0 minutes
# Step 196000 of 200000; TPS: 3243.62; ETA: 0.0 minutes
# Step 197000 of 200000; TPS: 3242.08; ETA: 0.0 minutes
# Step 198000 of 200000; TPS: 3240.95; ETA: 0.0 minutes
# Step 199000 of 200000; TPS: 3238.86; ETA: 0.0 minutes

# %%
# 5 chains seems to be the max for 2 flakes at a timestep size of 0.005
# for 2 chains, flake # does not matter at all, was able to go up to 12 flakes with ease
